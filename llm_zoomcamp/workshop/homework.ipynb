# %% [markdown]
# # dlt workshop. Homework

# %%
PREFIX="https://raw.githubusercontent.com/DataTalksClub/llm-zoomcamp/main/cohorts/2026/workshops/dlt/homework"

# !wget $PREFIX/agent.py
# !wget $PREFIX/ingest.py
# !wget $PREFIX/main.py
# !wget $PREFIX/.env.example -O .env
# Out:
# --2026-07-20 19:17:15--  https://raw.githubusercontent.com/DataTalksClub/llm-zoomcamp/main/cohorts/2026/workshops/dlt/homework/agent.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 240.1.27.228
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|240.1.27.228|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4379 (4.3K) [text/plain]
# Saving to: ‘agent.py’
#
# agent.py            100%[===================>]   4.28K  --.-KB/s    in 0s
#
# 2026-07-20 19:17:16 (23.2 MB/s) - ‘agent.py’ saved [4379/4379]
#
# --2026-07-20 19:17:16--  https://raw.githubusercontent.com/DataTalksClub/llm-zoomcamp/main/cohorts/2026/workshops/dlt/homework/ingest.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 240.1.27.228
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|240.1.27.228|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 739 [text/plain]
# Saving to: ‘ingest.py’
#
# ingest.py           100%[===================>]     739  --.-KB/s    in 0s
#
# 2026-07-20 19:17:16 (28.2 MB/s) - ‘ingest.py’ saved [739/739]
#
# --2026-07-20 19:17:16--  https://raw.githubusercontent.com/DataTalksClub/llm-zoomcamp/main/cohorts/2026/workshops/dlt/homework/main.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 240.1.27.228
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|240.1.27.228|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 677 [text/plain]
# Saving to: ‘main.py’
#
# main.py             100%[===================>]     677  --.-KB/s    in 0s
#
# 2026-07-20 19:17:17 (12.9 MB/s) - ‘main.py’ saved [677/677]
#
# --2026-07-20 19:17:17--  https://raw.githubusercontent.com/DataTalksClub/llm-zoomcamp/main/cohorts/2026/workshops/dlt/homework/.env.example
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 240.1.27.228
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|240.1.27.228|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 273 [text/plain]
# Saving to: ‘.env’
#
# .env                100%[===================>]     273  --.-KB/s    in 0s
#
# 2026-07-20 19:17:17 (23.7 MB/s) - ‘.env’ saved [273/273]

# %% [markdown]
# ## Question 1. Instrument the agent with Logfire
#
# Sign up for a free [Logfire](https://logfire.dev) account, create a
# project, and generate a write token. Put it in `.env` as
# `LOGFIRE_TOKEN`.
#
# Instrument the agent:
#
# ```python
# logfire.configure()
# logfire.instrument_pydantic_ai()
# ```
#
# Run the agent a few times with different questions and open your
# project on Logfire to see the traces.
#
# For the following query
#
# > How do I run Ollama locally?
#
# how many spans does a single agent run produce?
#
# Each span is either the agent run itself, an LLM call, or a tool call.
# The number can vary between runs because the model decides how many
# times to search.
#
# * 1
# * 5 [x]
# * 15
# * 30
